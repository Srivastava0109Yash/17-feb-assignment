# %% [markdown]
# ### Q1. What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use MongoDB over SQL databases?

# %% [markdown]
# __MongoDB__ is a popular document-oriented NoSQL database management system (DBMS) that uses a flexible document-based data model instead of traditional relational tables to store and manage data. MongoDB stores data in JSON-like documents with dynamic schemas, which makes it highly scalable, flexible, and efficient for handling unstructured or semi-structured data.

# %% [markdown]
# __Non-relational databases__, also known as NoSQL databases, are designed to store and manage large volumes of unstructured or semi-structured data, such as text, images, videos, and sensor data. Unlike relational databases, NoSQL databases don't use fixed schemas or tables and don't require a predefined data model. Instead, they use flexible data structures, such as key-value pairs, document-oriented databases, graph databases, or column-family stores, to store and retrieve data.

# %% [markdown]
# There are several scenarios where MongoDB may be preferred over traditional SQL databases:
#
# __High scalability__: MongoDB is highly scalable, and it can handle large volumes of data and high traffic loads, making it a good choice for large-scale applications and big data processing.
#
# __Flexibility__: MongoDB's dynamic schema allows developers to easily change data structures and add new fields without having to modify the entire database schema, making it more flexible and agile than traditional SQL databases.
#
# __Performance__: MongoDB's document-oriented data model enables faster read and write operations compared to traditional SQL databases, especially when dealing with complex and unstructured data.
#
# __Cloud-native__: MongoDB has built-in support for cloud-based deployments, making it easier to set up and manage in cloud environments such as AWS, Azure, or Google Cloud Platform.

# %% [markdown]
# ### Q2. State and Explain the features of MongoDB.

# %% [markdown]
# MongoDB is a popular document-oriented NoSQL database management system that offers several features that make it a powerful and flexible database solution. Some of the key features of MongoDB are:

# %% [markdown]
# __Document-Oriented Data Model__: MongoDB stores data in documents, which are JSON-like data structures that can have variable fields, making it more flexible than traditional relational databases.
#
# __Scalability__: MongoDB can easily scale horizontally across multiple nodes, allowing it to handle large volumes of data and high traffic loads.
#
# __High Performance__: MongoDB's document-oriented data model enables faster read and write operations compared to traditional SQL databases, especially when dealing with complex and unstructured data.
#
# __Indexing and Querying__: MongoDB supports indexing and querying of data, making it easier to retrieve data efficiently.
#
# __Flexible Data Schema__: MongoDB's flexible data schema allows users to easily add or remove fields without having to change the entire schema, making it more agile and responsive to changing data needs.
#
# __Native Cloud Support__: MongoDB has built-in support for cloud-based deployments, making it easier to set up and manage in cloud environments such as AWS, Azure, or Google Cloud Platform

# %% [markdown]
# ### Q3. Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.

# %%
pip install pymongo

# %%
# Importing the necessary libraries
import pymongo

# Establishing a connection with MongoDB
client = pymongo.MongoClient("mongodb+srv://Yashsri0109:Yash0109@cluster0.akkgowo.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
db
# Out:
# Database(MongoClient(host=['ac-lhwrlwi-shard-00-02.akkgowo.mongodb.net:27017', 'ac-lhwrlwi-shard-00-00.akkgowo.mongodb.net:27017', 'ac-lhwrlwi-shard-00-01.akkgowo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-9r7lc7-shard-0', tls=True), 'test')

# %%
# Creating a database in MongoDB
db=client['Yash']

# %%
# Creating a collection in the database
col_my=db['records']

# %% [markdown]
# ### Q4. Using the database and the collection created in question number 3, write a code to insert one record, and insert many records. Use the find() and find_one() methods to print the inserted record.

# %%
# data we have:
data={'name':"Yash Srivastava",
      'class':'Data Science',
      'time':'flexi'}

# %% [markdown]
# ##### Insert one record

# %%
col_my.insert_one(data)

# %%
from IPython.display import Image
Image("C:/Users/Yash/Pictures/Screenshots/Screenshot_20230218_124941.png")

# %%
# data we have:
data2=[
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %% [markdown]
# ##### Insert many records

# %%
col_my.insert_many(data2)

# %%
from IPython.display import Image
Image("C:/Users/Yash/Pictures/Screenshots/Screenshot_20230218_125151.png")

# %% [markdown]
# ##### Use find() method

# %%
for i in col_my.find():
    print(i)
# Out:
# {'_id': ObjectId('63f07bc1307e6354480b6479'), 'name': 'Yash Srivastava', 'class': 'Data Science', 'time': 'flexi'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18b'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18c'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18d'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18e'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18f'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63f07c694d8cc3280a08f190'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('63f07c694d8cc3280a08f191'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('63f07c694d8cc3280a08f192'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('63f07c694d8cc3280a08f193'), 'name': 'Ben', 'address': 'Park Lane 38'}
# ...

# %%
for i in col_my.find({"name":"Yash Srivastava"}):
    print(i)
# Out:
# {'_id': ObjectId('63f07bc1307e6354480b6479'), 'name': 'Yash Srivastava', 'class': 'Data Science', 'time': 'flexi'}

# %% [markdown]
# ##### Using find_one():

# %%
col_my.find_one()
# Out:
# {'_id': ObjectId('63f07bc1307e6354480b6479'),
#  'name': 'Yash Srivastava',
#  'class': 'Data Science',
#  'time': 'flexi'}

# %% [markdown]
# ### Q5.   Explain how you can use the find() method to query the MongoDB database. Write a simple code to

# %% [markdown]
# The find() method is used to query a MongoDB database and retrieve documents that match a specified set of criteria. It takes an optional query object as a parameter, which can be used to specify the selection criteria for the query.

# %%
#code:
for i in col_my.find():
    print(i)
# Out:
# {'_id': ObjectId('63f07bc1307e6354480b6479'), 'name': 'Yash Srivastava', 'class': 'Data Science', 'time': 'flexi'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18b'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18c'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18d'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18e'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18f'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63f07c694d8cc3280a08f190'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('63f07c694d8cc3280a08f191'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('63f07c694d8cc3280a08f192'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('63f07c694d8cc3280a08f193'), 'name': 'Ben', 'address': 'Park Lane 38'}
# ...

# %%
for i in col_my.find({"name":"Susan"}):
    print(i)
# Out:
# {'_id': ObjectId('63f07c694d8cc3280a08f191'), 'name': 'Susan', 'address': 'One way 98'}

# %% [markdown]
# ### Q6. Explain the sort() method. Give an example to demonstrate sorting in MongoDB.

# %% [markdown]
# The sort() method in MongoDB is used to sort the documents in a collection based on a specified field or fields. The method takes one or more sort keys as arguments, each of which can be either a field name or a tuple consisting of a field name and a sort direction.By default, the sort() method sorts the documents in ascending order based on the specified field(s).

# %%
# Inserting some records into the collection
mylist = [
  { "name": "John", "address": "Highway 37", "age": 30 },
  { "name": "Peter", "address": "Lowstreet 27", "age": 25 },
  { "name": "Amy", "address": "Apple st 652", "age": 35 },
  { "name": "Hannah", "address": "Mountain 21", "age": 28 },
  { "name": "Michael", "address": "Valley 345", "age": 40 }
]

# %%
col_my.insert_many(mylist)

# %% [markdown]
# ##### sorting in descending order of 'age'

# %%
for i in col_my.find().sort("age",pymongo.DESCENDING):
    print(i)
# Out:
# {'_id': ObjectId('63f08d454d8cc3280a08f19b'), 'name': 'Michael', 'address': 'Valley 345', 'age': 40}
# {'_id': ObjectId('63f08d454d8cc3280a08f199'), 'name': 'Amy', 'address': 'Apple st 652', 'age': 35}
# {'_id': ObjectId('63f08d454d8cc3280a08f197'), 'name': 'John', 'address': 'Highway 37', 'age': 30}
# {'_id': ObjectId('63f08d454d8cc3280a08f19a'), 'name': 'Hannah', 'address': 'Mountain 21', 'age': 28}
# {'_id': ObjectId('63f08d454d8cc3280a08f198'), 'name': 'Peter', 'address': 'Lowstreet 27', 'age': 25}
# {'_id': ObjectId('63f07bc1307e6354480b6479'), 'name': 'Yash Srivastava', 'class': 'Data Science', 'time': 'flexi'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18e'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18b'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18f'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63f07c694d8cc3280a08f18d'), 'name': 'Michael', 'address': 'Valley 345'}
# ...

# %% [markdown]
# ### Q7. Explain why delete_one(), delete_many(), and drop() is used.

# %% [markdown]
# __delete_one()__: This method is used to delete a single document that matches the specified criteria. If there are multiple documents that match the criteria, it will only delete the first one that it finds.
#
# __delete_many()__: This method is used to delete all documents that match the specified criteria. It deletes all the documents that satisfy the condition mentioned.
#
# __drop()__: This method is used to delete an entire collection from the database. It permanently removes all documents in the collection and deletes the collection schema.

# %%
# Deleting a single document from the collection
query = { "name": "Amy" }
col_my.delete_one(query)

# Deleting multiple documents from the collection
query = { "age": { "$gt": 30 } }
col_my.delete_many(query)

# Deleting the entire collection
col_my.drop()

# %%
Image("C:/Users/Yash/Pictures/Screenshots/Screenshot_20230218_141653.png")

# %% [markdown]
# #### Our Database Named "Yash" is truncated
